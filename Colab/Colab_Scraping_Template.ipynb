# %% [markdown]
# # B.League Scraping (Colab)\n
# Run cells from top to bottom.

# %%
from google.colab import drive\n
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/git-tj999/B_Stats_Site/Colab

# %%
# !pip install -r requirements.txt

# %%
# !python run_scrape_colab.py \\n
  --date 2024-10-05 \\n
  --season 2024-25 \\n
  --output-dir /content/drive/MyDrive/git-tj999/B_Stats_Site/scraper/data \\n
  --max-workers 8

# %%
# !ls -lh /content/drive/MyDrive/git-tj999/B_Stats_Site/scraper/data | tail -n 5
